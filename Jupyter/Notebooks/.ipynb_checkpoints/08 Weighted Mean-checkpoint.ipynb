# %%
import pandas as pd
import os
from scipy.stats import ttest_ind
import numpy as np
from scipy import stats
from sklearn.metrics import mean_squared_error
from math import sqrt

# %% [markdown]
# # eQTL

# %%
header=pd.read_csv('/nfs/research1/zerbino/jhidalgo/inteql_GTEX_v8/data/original-data/eQTL_catalogue/lead_pairs/split/header.tsv',sep='\t').columns

# %%
samples=header[header.str.contains('beta')]

# %%
chr1=pd.read_csv('/nfs/research1/zerbino/jhidalgo/inteql_GTEX_v8/data/original-data/eQTL_catalogue/lead_pairs/split/chr1.tsv',sep='\t',header=None,names=header.tolist(),usecols=samples.tolist())

# %%
chr1
# Out:
#       Alasoo_2018.macrophage_IFNg.beta  \
# 0                             0.014878
# 1                             0.010908
# 2                             0.032490
# 3                            -0.015936
# 4                             0.017091
# ...                                ...
# 5141                               NaN
# 5142                               NaN
# 5143                               NaN
# 5144                         -0.835799
# 5145                         -0.162653
#
#       Alasoo_2018.macrophage_IFNg+Salmonella.beta  \
# 0                                        0.019929
# 1                                       -0.003541
# 2                                        0.035531
# 3                                       -0.023199
# 4                                        0.040628
# ...                                           ...
# 5141                                          NaN
# 5142                                          NaN
# 5143                                          NaN
# 5144                                    -0.444700
# 5145                                    -0.402694
#
#       Alasoo_2018.macrophage_naive.beta  \
# 0                              0.007145
# 1                              0.007549
# 2                             -0.010889
# 3                             -0.003959
# 4                              0.002270
# ...                                 ...
# 5141                                NaN
# 5142                                NaN
# 5143                                NaN
# 5144                          -0.555345
# 5145                          -0.188404
#
#       Alasoo_2018.macrophage_Salmonella.beta  BLUEPRINT_PE.T-cell.beta  \
# 0                                   0.008409                 -0.009101
# 1                                   0.010561                 -0.016851
# 2                                   0.005276                 -0.024435
# 3                                  -0.011975                  0.006480
# 4                                  -0.012849                 -0.046222
# ...                                      ...                       ...
# 5141                                     NaN                       NaN
# 5142                                     NaN                       NaN
# 5143                                     NaN                       NaN
# 5144                               -1.044910                 -0.515010
# 5145                               -1.284650                 -0.188205
#
#       BLUEPRINT_SE.monocyte.beta  BLUEPRINT_SE.neutrophil.beta  \
# 0                      -0.003149                      0.012835
# 1                      -0.032392                      0.011638
# 2                      -0.002244                      0.015308
# 3                       0.006495                      0.001639
# 4                      -0.001068                      0.026307
# ...                          ...                           ...
# 5141                         NaN                           NaN
# 5142                         NaN                           NaN
# 5143                         NaN                           NaN
# 5144                   -1.162060                     -0.775167
# 5145                   -0.020301                      0.033504
#
#       BrainSeq.brain.beta  FUSION.adipose_naive.beta  \
# 0               -0.064450                  -0.124903
# 1               -0.059007                  -0.112610
# 2               -0.017674                  -0.078033
# 3                0.040951                   0.102934
# 4               -0.033465                  -0.096427
# ...                   ...                        ...
# 5141             0.169476                        NaN
# 5142            -0.481553                        NaN
# 5143            -0.039183                        NaN
# 5144                  NaN                        NaN
# 5145            -0.115315                  -0.343010
#
#       FUSION.muscle_naive.beta  ...  Schmiedel_2018.Th1_memory.beta  \
# 0                    -0.055078  ...                       -0.053285
# 1                    -0.064238  ...                       -0.061821
# 2                    -0.031212  ...                       -0.069205
# 3                     0.043425  ...                        0.056723
# 4                    -0.033965  ...                       -0.067252
# ...                        ...  ...                             ...
# 5141                       NaN  ...                             NaN
# 5142                       NaN  ...                             NaN
# 5143                       NaN  ...                             NaN
# 5144                       NaN  ...                             NaN
# 5145                       NaN  ...                       -1.749810
#
#       Schmiedel_2018.Th2_memory.beta  Schmiedel_2018.Treg_memory.beta  \
# 0                          -0.064724                        -0.051557
# 1                          -0.067910                        -0.071500
# 2                          -0.108168                        -0.064846
# 3                           0.029918                         0.034181
# 4                          -0.077675                        -0.066157
# ...                              ...                              ...
# 5141                             NaN                              NaN
# 5142                             NaN                              NaN
# 5143                             NaN                              NaN
# 5144                             NaN                              NaN
# 5145                       -0.687764                         0.076683
#
#       Schmiedel_2018.Treg_naive.beta  \
# 0                          -0.012166
# 1                          -0.049701
# 2                          -0.073328
# 3                           0.002864
# 4                          -0.090915
# ...                              ...
# 5141                             NaN
# 5142                             NaN
# 5143                        0.222462
# 5144                             NaN
# 5145                       -0.795047
#
#       Schwartzentruber_2018.sensory_neuron.beta  TwinsUK.blood.beta  \
# 0                                     -0.004896           -0.102931
# 1                                     -0.003615           -0.037607
# 2                                      0.047522           -0.057850
# 3                                     -0.017142            0.089044
# 4                                     -0.013857           -0.074314
# ...                                         ...                 ...
# 5141                                        NaN                 NaN
# 5142                                        NaN                 NaN
# 5143                                        NaN            0.004210
# 5144                                  -1.105700           -0.384165
# 5145                                   0.768013            0.059167
#
#       TwinsUK.fat.beta  TwinsUK.LCL.beta  TwinsUK.skin.beta  \
# 0            -0.101464         -0.078311          -0.172428
# 1            -0.049467         -0.055712          -0.085808
# 2            -0.044238         -0.064538          -0.098973
# 3             0.070987          0.067175           0.133267
# 4            -0.068720         -0.062703          -0.106860
# ...                ...               ...                ...
# 5141               NaN               NaN                NaN
# 5142               NaN               NaN                NaN
# 5143          0.006468          0.006864          -0.009389
# 5144         -0.620556               NaN          -1.014790
# 5145         -0.300232               NaN          -0.406140
#
#       van_de_Bunt_2015.pancreatic_islet.beta
# 0                                  -0.056237
# 1                                  -0.053505
# 2                                  -0.026313
# 3                                   0.060757
# 4                                  -0.052091
# ...                                      ...
# 5141                                     NaN
# 5142                                     NaN
# 5143                               -0.090711
# 5144                               -0.640082
# 5145                                0.061558
#
# [5146 rows x 94 columns]

# %%
target=chr1.columns[chr1.columns.str.contains('monocyte.beta')]

# %%
# eqtl_base=chr1.columns[~ chr1.columns.str.contains('monocyte')]

# %% [markdown]
# # TPMs

# %%
os.chdir('/nfs/research1/zerbino/jhidalgo/inteql_GTEX_v8/data/original-data/eQTL_catalogue/tpms/tpm/')

# %%
tpms={}
for file in os.listdir():
    if file.endswith('_median_tpm.tsv'):
        exp=file.rstrip('_median_tpm.tsv')
        tpms[exp]=pd.read_csv(file,sep='\t')

# %%
genes=[]
for i in tpms:
    genes=genes+list(tpms[i]['phenotype_id'].unique())

# %%
merged=pd.DataFrame()
for i in tpms:
    table=tpms[i].pivot_table(values='median_tpm',columns=['study','qtl_group'],index='phenotype_id')
    if merged.empty: merged=table
    else:
        merged=merged.merge(table,left_index=True,right_index=True,how='outer')

# %%
merged
# Out:
# study           BLUEPRINT_PE   HipSci     GTEx                       \
# qtl_group             T-cell     iPSC      LCL adipose_subcutaneous
# phenotype_id
# ENSG00000000419      168.686  224.106  163.772              111.776
# ENSG00000000457       36.625    7.625   17.277               12.537
# ENSG00000000460        8.837   27.067   15.446                4.564
# ENSG00000000938        1.666    0.474  173.260               65.184
# ENSG00000000971        1.771    0.016    0.222              180.178
# ...                      ...      ...      ...                  ...
# ENSG00000286266        0.000    0.000    2.122                0.000
# ENSG00000286269        0.000    0.000    0.000                0.000
# ENSG00000286270        0.000    0.000    0.000                0.000
# ENSG00000286271        0.905    0.085    0.278                0.440
# ENSG00000286272        0.000    0.000    0.000                0.000
#
# study                                                                        \
# qtl_group       adipose_visceral adrenal_gland artery_aorta artery_coronary
# phenotype_id
# ENSG00000000419          114.238       151.027      110.898         106.522
# ENSG00000000457            9.638        12.616        8.237           9.487
# ENSG00000000460            3.246         2.998        2.749           3.096
# ENSG00000000938           59.219        20.729       16.019          31.762
# ENSG00000000971           81.223        51.793      165.800         374.025
# ...                          ...           ...          ...             ...
# ENSG00000286266            0.000         0.000        0.000           0.000
# ENSG00000286269            0.000         0.000        0.000           0.000
# ENSG00000286270            0.000         0.000        0.000           0.000
# ENSG00000286271            0.255         0.191        0.140           0.288
# ENSG00000286272            0.000         0.000        0.000           0.000
#
# study                                   ...      Schmiedel_2018  \
# qtl_group       artery_tibial    blood  ... monocyte_CD16_naive
# phenotype_id                            ...
# ENSG00000000419       110.239   17.977  ...             134.002
# ENSG00000000457         9.520    3.411  ...              23.140
# ENSG00000000460         3.165    0.687  ...              17.086
# ENSG00000000938         9.144  748.385  ...            1987.121
# ENSG00000000971       294.033    0.358  ...               0.027
# ...                       ...      ...  ...                 ...
# ENSG00000286266         0.000    0.000  ...               0.000
# ENSG00000286269         0.000    0.000  ...               0.000
# ENSG00000286270         0.000    0.000  ...               0.000
# ENSG00000286271         0.173    0.061  ...               0.000
# ENSG00000286272         0.000    0.000  ...               0.000
#
# study                                 FUSION                  Alasoo_2018  \
# qtl_group       monocyte_naive adipose_naive muscle_naive macrophage_IFNg
# phenotype_id
# ENSG00000000419         90.901       100.392       80.784         105.563
# ENSG00000000457          6.705        11.164        5.890          14.949
# ENSG00000000460          4.531         3.437        1.038           2.616
# ENSG00000000938       1553.818        45.761        3.876          31.412
# ENSG00000000971          0.210       120.803       14.348          83.252
# ...                        ...           ...          ...             ...
# ENSG00000286266          0.000         0.000        0.000           0.000
# ENSG00000286269          0.000         0.000        0.011           0.000
# ENSG00000286270          0.000         0.000        0.000           0.000
# ENSG00000286271          0.000         0.096        0.052           0.000
# ENSG00000286272          0.000         0.000        1.226           0.000
#
# study                                                             \
# qtl_group       macrophage_IFNg+Salmonella macrophage_Salmonella
# phenotype_id
# ENSG00000000419                     53.610                79.409
# ENSG00000000457                     10.305                 9.252
# ENSG00000000460                      0.874                 3.619
# ENSG00000000938                    113.584                40.332
# ENSG00000000971                     52.710                 3.288
# ...                                    ...                   ...
# ENSG00000286266                      0.000                 0.000
# ENSG00000286269                      0.000                 0.000
# ENSG00000286270                      0.000                 0.000
# ENSG00000286271                      0.000                 0.000
# ENSG00000286272                      0.000                 0.000
#
# study                            Lepik_2017 Schwartzentruber_2018
# qtl_group       macrophage_naive      blood        sensory_neuron
# phenotype_id
# ENSG00000000419          135.585     93.728               118.309
# ENSG00000000457            8.842     13.254                12.061
# ENSG00000000460           11.864      2.192                 2.600
# ENSG00000000938           21.560    867.557                 0.051
# ENSG00000000971            1.852      2.119                 1.288
# ...                          ...        ...                   ...
# ENSG00000286266            0.000      0.000                 0.000
# ENSG00000286269            0.000      0.000                 0.248
# ENSG00000286270            0.000      0.000                 0.000
# ENSG00000286271            0.000      0.000                 0.094
# ENSG00000286272            0.000      0.000                 0.000
#
# [34120 rows x 95 columns]

# %%
table=merged.groupby(level=1,axis=1).mean()

# %%
table=table[(table>100).any(axis=1)]

# %%
table
# Out:
# qtl_group        B-cell_naive  CD4_T-cell_anti-CD3-CD28  CD4_T-cell_naive  \
# phenotype_id
# ENSG00000000419       149.058                   247.810           156.373
# ENSG00000000938       209.973                     1.398             4.287
# ENSG00000000971         0.000                     0.000             0.120
# ENSG00000001036        14.679                     3.805            15.484
# ENSG00000001084        15.130                    24.050            19.419
# ...                       ...                       ...               ...
# ENSG00000286076         0.000                     0.000             0.000
# ENSG00000286169         0.208                     0.211             0.233
# ENSG00000286190        22.648                    10.923            50.988
# ENSG00000286214         1.844                     0.613             3.501
# ENSG00000286256         0.000                     0.357             0.000
#
# qtl_group        CD8_T-cell_anti-CD3-CD28  CD8_T-cell_naive        LCL  \
# phenotype_id
# ENSG00000000419                   240.985           137.430  165.00625
# ENSG00000000938                     1.807             6.019  189.66225
# ENSG00000000971                     0.000             0.134    0.06225
# ENSG00000001036                     3.208            10.914   42.89650
# ENSG00000001084                    31.533            23.846   10.16300
# ...                                   ...               ...        ...
# ENSG00000286076                     0.000             0.000    0.00000
# ENSG00000286169                     0.375             0.288   40.77825
# ENSG00000286190                    11.382            54.053    6.88700
# ENSG00000286214                     1.743            11.349    0.28600
# ENSG00000286256                     0.231             0.000    2.98600
#
# qtl_group        NK-cell_naive    T-cell  Tfh_memory  Th1-17_memory  ...  \
# phenotype_id                                                         ...
# ENSG00000000419        124.902  134.1230     129.115        166.599  ...
# ENSG00000000938       1176.406   73.4675       5.568          0.294  ...
# ENSG00000000971          2.272    1.0885       3.820         55.581  ...
# ENSG00000001036         41.698   23.2520      19.603         21.640  ...
# ENSG00000001084         44.200   21.9570      16.975         31.130  ...
# ...                        ...       ...         ...            ...  ...
# ENSG00000286076          0.000    0.0000       0.000          0.000  ...
# ENSG00000286169          0.944   33.3320       0.179          0.170  ...
# ENSG00000286190         41.543   39.2395      54.032         38.009  ...
# ENSG00000286214          0.267    0.6095       1.206          1.532  ...
# ENSG00000286256          0.000    1.2010       0.000          0.000  ...
#
# qtl_group          skin  skin_not_sun_exposed  skin_sun_exposed  \
# phenotype_id
# ENSG00000000419  99.062                97.559            95.092
# ENSG00000000938  15.784                11.185            12.148
# ENSG00000000971  55.905                50.090            94.605
# ENSG00000001036  42.308                24.002            28.012
# ENSG00000001084  21.192                20.788            17.527
# ...                 ...                   ...               ...
# ENSG00000286076   0.000                 0.000             0.000
# ENSG00000286169  16.145                 6.131             6.553
# ENSG00000286190  54.901                43.676            40.709
# ENSG00000286214   3.347                 1.798             1.657
# ENSG00000286256   0.000                 0.120             0.143
#
# qtl_group        small_intestine   spleen  stomach   testis  thyroid   uterus  \
# phenotype_id
# ENSG00000000419          103.814  104.117   99.939  152.917  124.013  129.334
# ENSG00000000938           27.220  368.788   10.828    8.361   26.865   30.602
# ENSG00000000971           59.529   11.240   35.381   11.961  163.453   13.748
# ENSG00000001036           71.661   56.614   62.511   24.000   71.818   59.471
# ENSG00000001084           40.729   37.363   29.813   15.047   31.284   16.065
# ...                          ...      ...      ...      ...      ...      ...
# ENSG00000286076            0.000    1.091    0.000    0.000    0.000    0.000
# ENSG00000286169            3.516   12.202    1.415    9.696    2.760    2.271
# ENSG00000286190           30.049   57.334   10.545   52.564   37.688   75.361
# ENSG00000286214            3.745   11.611    1.561    3.321    7.295   10.999
# ENSG00000286256            0.124    2.035    0.125    7.409    0.122    0.000
#
# qtl_group         vagina
# phenotype_id
# ENSG00000000419  103.121
# ENSG00000000938   19.265
# ENSG00000000971   22.866
# ENSG00000001036   50.062
# ENSG00000001084   30.450
# ...                  ...
# ENSG00000286076    0.000
# ENSG00000286169    4.396
# ENSG00000286190   69.609
# ENSG00000286214    1.435
# ENSG00000286256    0.103
#
# [10606 rows x 85 columns]

# %% [markdown]
# # Diff Exp gene detection

# %%
from scipy.stats import ttest_ind

# %%
for tissue in table.columns:
    for gene in table.index:
        ttest=ttest_ind(table[tissue][gene],table.loc[gene].drop(tissue))
        break
    break
# Out:
# /homes/jhidalgo/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3583: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /homes/jhidalgo/.local/lib/python3.8/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Common naming

# %%
table.columns

# %%
chr1.columns

# %%
naming={}
for i in table.columns:
    if len(chr1.columns[chr1.columns.str.contains(i+'.beta')].tolist())>0:
        naming[i]=chr1.columns[chr1.columns.str.contains(i+'.beta')].tolist()

# %%
tpm_base=table[list(naming.keys())]

# %%
chr1_names=[j for i in list(naming.values()) for j in i]

# %%
eqtl_base=chr1[chr1_names]

# %%
weights=tpm_base.corr()['monocyte'].drop('monocyte')

# %%
weights
# Out:
# qtl_group
# B-cell_naive                0.264554
# CD4_T-cell_anti-CD3-CD28    0.179548
# CD4_T-cell_naive            0.241829
# CD8_T-cell_anti-CD3-CD28    0.211317
# CD8_T-cell_naive            0.243409
#                               ...
# stomach                     0.048754
# testis                      0.029001
# thyroid                     0.255170
# uterus                      0.244143
# vagina                      0.496249
# Name: monocyte, Length: 82, dtype: float64

# %%
weighted_eqtls={}
max_weight={}
for i in naming.keys():
    if i == 'monocyte':
        continue
    weighted_eqtls[i]=eqtl_base[naming[i]].mean(axis=1)*weights[i]
    max_weight[i]=eqtl_base[naming[i]].mean(axis=1).notna()*weights[i]

# %%
prediction=pd.DataFrame(weighted_eqtls).sum(axis=1)/pd.DataFrame(max_weight).sum(axis=1)

# %%
pred_real=pd.DataFrame({'Prediction':prediction,'Real':chr1['BLUEPRINT_SE.monocyte.beta']}).dropna()

# %%
pred_real.corr()['Prediction']['Real']
# Out:
# 0.7033515422089349

# %%
np.sqrt(mean_squared_error(pred_real['Prediction'],pred_real['Real']))
# Out:
# 0.3361115693822852

# %%
#### PLOT

# %%
def real_pred_plot(y_test,y_pred):
    plot=((
        ggplot(pd.DataFrame({'y_test':y_test,'y_pred':y_pred}),aes(x='y_test',y='y_pred'))+
            geom_point()+
            geom_smooth(colour='red')
    ))
    return(plot)

# %%
real_pred_plot(pred_real['Prediction'],pred_real['Real'])
# Out:
# <ggplot: (2961582710221)>
